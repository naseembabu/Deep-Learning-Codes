# %% [markdown]
# <a href="https://colab.research.google.com/github/naseembabu/Deep-Learning-Codes/blob/main/Prophet_on_Time_Series_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from fbprophet import Prophet
# https://facebook.github.io/prophet/docs/quick_start.html
 
 
import pandas as pd
# https://pandas.pydata.org/docs/
 
import numpy as np
# https://numpy.org/doc/stable/about.html
 
from math import sqrt
# https://docs.python.org/3/library/math.html
from datetime import datetime
# https://docs.python.org/3/library/datetime.html
 
from matplotlib import pyplot as plt
# https://matplotlib.org/index.html
import seaborn as sns
# https://seaborn.pydata.org/
 
from sklearn.metrics import mean_squared_error
# https://scikit-learn.org/stable/getting_started.html
 
 
from scipy import stats
# https://docs.scipy.org/doc/scipy/reference/

# %%
data = pd.read_csv('https://raw.githubusercontent.com/n28neeraj/TImeSeries_Tutorial/master/AirPassengers.csv')

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
# data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/AirPassengers.csv')

# %%
# data = pd.read_csv('AirPassengers.csv')

# %%
data.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
data.dtypes
# Out:
# Month          object
# #Passengers     int64
# dtype: object

# %%
data['Month'] = pd.DatetimeIndex(data['Month'])
data.dtypes
# Out:
# Month          datetime64[ns]
# #Passengers             int64
# dtype: object

# %%
data = data.rename(columns={'Month': 'ds', '#Passengers': 'y'})

data.head(5)
# Out:
#           ds    y
# 0 1949-01-01  112
# 1 1949-02-01  118
# 2 1949-03-01  132
# 3 1949-04-01  129
# 4 1949-05-01  121

# %%
ax = data.set_index('ds').plot(figsize=(12, 8))
ax.set_ylabel('Monthly Number of Airline Passengers')
ax.set_xlabel('Date')

plt.show()

# %%
# set the uncertainty interval to 95% (the Prophet default is 80%)
my_model = Prophet(interval_width=0.95)

# %%
trainLen = 108
train = data[:trainLen]
test = data[trainLen:]

# %%
my_model.fit(train)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_dates = my_model.make_future_dataframe(periods=36, freq='MS')
future_dates.tail()
# Out:
#             ds
# 139 1960-08-01
# 140 1960-09-01
# 141 1960-10-01
# 142 1960-11-01
# 143 1960-12-01

# %%
forecast = my_model.predict(future_dates)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds        yhat  yhat_lower  yhat_upper
# 139 1960-08-01  547.347790  514.904098  578.091197
# 140 1960-09-01  510.625969  481.936214  540.092490
# 141 1960-10-01  479.773547  449.153218  509.026019
# 142 1960-11-01  454.387200  423.795720  485.858530
# 143 1960-12-01  481.238389  449.178175  511.993663

# %%
predicted = forecast['yhat'][108:]

# %%
error = sqrt(mean_squared_error(test['y'], predicted))
print('Test RMSE: %.3f' % error)
# Out:
# Test RMSE: 44.567

# %%
my_model.plot(forecast, uncertainty=True)

# %%
plt.figure(figsize=(15, 5))                           #set the plot size
forecast['yhat_upper'].plot(label = 'yhat_upper')     #plot the predicted upper bound
forecast['yhat'].plot(label = 'yhat')                 #plot the predicted mean
forecast['yhat_lower'].plot(label = 'yhat_lower')     #plot the predicted lower bound
plt.legend()

# %%
#plot the components obtained by prophet model
fig = my_model.plot_components(forecast)

# %%
#plotting the forecast values along with actual value for a comparision only for test data

plt.figure(figsize=(15, 5))                                            #set the plot size
forecast['yhat_upper'][trainLen:].plot(label = 'yhat_upper')     #plot the predicted upper bound only for test data
forecast['yhat'][trainLen:].plot(label = 'yhat')                 #plot the predicted mean only for test data
forecast['yhat_lower'][trainLen:].plot(label = 'yhat_lower')     #plot the predicted lower bound only for test data
data['y'][trainLen:].plot(label = 'Actual # of Passengers')        #plot the actual value of time series only for test data
plt.legend()
